# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d8f838d-1140-436d-90ce-fa959be5a6e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d8f838d-1140-436d-90ce-fa959be5a6e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Big Mart Sales.csv to Big Mart Sales (3).csv

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid' ,font_scale = 1.5, color_codes=True)
import warnings
warnings.filterwarnings('ignore')
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Big Mart Sales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(value=df['Item_Weight'].mean())
df['Outlet_Size'] = df['Outlet_Size'].fillna("Medium")

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
sns.countplot(df['Item_Fat_Content'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df['Item_Outlet_Sales'],x=df['Item_Fat_Content'],palette='Reds')
plt.title('Outlet Sales vs Fat Content')
# Out:
# Text(0.5, 1.0, 'Outlet Sales vs Fat Content')

# %%
sns.scatterplot(df['Item_Weight'],df['Item_Outlet_Sales'])

# %%
p = sns.pairplot(df)

# %% [markdown]
# Checking for Linearity

# %%
p = sns.pairplot(df, x_vars=['Item_Visibility','Item_MRP','Item_Weight'], y_vars='Item_Outlet_Sales', size=7, aspect=0.7)

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df['Item_Outlet_Sales'],x=df['Outlet_Location_Type'],palette='Reds')
plt.title('Outlet Sales vs Fat Content')
# Out:
# Text(0.5, 1.0, 'Outlet Sales vs Fat Content')

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=df['Item_Outlet_Sales'],x=df['Item_Type'],palette='Reds')
plt.title('Outlet Sales vs Item Type')
# Out:
# Text(0.5, 1.0, 'Outlet Sales vs Item Type')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df["Outlet_Establishment_Year"].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
df.drop(['Item_Identifier'],axis=1,inplace=True)

# %%
cat_atr = ["Item_Fat_Content","Item_Type","Outlet_Identifier","Outlet_Size","Outlet_Establishment_Year","Outlet_Location_Type","Outlet_Type"]
num_atr = ["Item_Weight","Item_Visibility","Item_MRP","Item_Outlet_Sales"]

# %%
df.shape
# Out:
# (8523, 11)

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
df[num_atr] = ss.fit_transform(df[num_atr])

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

df[cat_atr] = df[cat_atr].apply(le.fit_transform)

# %%
X = df.drop(columns=['Item_Outlet_Sales'])
y = df['Item_Outlet_Sales']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 0,test_size=0.25)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
y_pred = regr.predict(X_train)

# %%
print("R squared: {}".format(r2_score(y_true=y_train,y_pred=y_pred)))
# Out:
# R squared: 0.5105823537633691

# %% [markdown]
#  Mean of Residuals
# Residuals as we know are the differences between the true value and the predicted value. One of the assumptions of linear regression is that the mean of the residuals should be zero. So let's find out.

# %%
residuals = y_train.values-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals -5.669223955532714e-17

# %% [markdown]
# Check for Homoscedasticity

# %%
p = sns.scatterplot(y_pred,residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')

# %% [markdown]
# Goldfeld Quandt Test
# Null Hypothesis: Error terms are homoscedastic
#
# Alternative Hypothesis: Error terms are heteroscedastic.

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, X_train)
lzip(name, test)
# Out:
# [('F statistic', 0.9593039370688458), ('p-value', 0.8794874015004769)]

# %% [markdown]
# Since p value is more than 0.05 in Goldfeld Quandt Test, we can't reject it's null hypothesis that error terms are homoscedastic. Good.
#
#
# Bartlett’s test tests the null hypothesis that all input samples are from populations with equal variances.

# %% [markdown]
# Check for Normality of error terms/residuals

# %%
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')

# %% [markdown]
# The residual terms are pretty much normally distributed for the number of test points we took.

# %% [markdown]
# No autocorrelation of residuals

# %%
plt.figure(figsize=(10,5))
p = sns.lineplot(y_pred,residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')

# %% [markdown]
# Checking for autocorrelation To ensure the absence of autocorrelation we use Ljungbox test.
#
#
# Null Hypothesis: Autocorrelation is absent.
#
# Alternative Hypothesis: Autocorrelation is present.

# %%
from statsmodels.stats import diagnostic as diag
min(diag.acorr_ljungbox(residuals , lags = 40)[1])
# Out:
# 0.2664471938049481

# %% [markdown]
# We reject null hypothesis.

# %%
import statsmodels.api as sm

# %%
# autocorrelation
sm.graphics.tsa.plot_acf(residuals, lags=40)
plt.show()

# %%
sm.graphics.tsa.plot_pacf(residuals, lags=40)
plt.show()

# %% [markdown]
# No perfect multicollinearity

# %%
plt.figure(figsize=(20,20)) 
p=sns.heatmap(df.corr(), annot=True,cmap='RdYlGn',square=True)
